# %%
import numpy as np
np.random.seed(123)
data = np.random.random(10)

# %%
from astropy.stats import sigma_clipped_stats
for i in range(20):
    avg, med, std = sigma_clipped_stats(data, sigma=1, iters=i)
    print(f"N_iter {i}: {avg:.3f}, {med:.3f}, {std:.3f}")
# Out:
# N_iter 0: 1.503, 0.565, 2.982
# N_iter 1: 0.513, 0.532, 0.266
# N_iter 2: 0.528, 0.546, 0.145
# N_iter 3: 0.550, 0.554, 0.081
# N_iter 4: 0.563, 0.563, 0.042
# N_iter 5: 0.565, 0.564, 0.022
# N_iter 6: 0.564, 0.563, 0.013
# N_iter 7: 0.561, 0.560, 0.008
# N_iter 8: 0.558, 0.557, 0.005
# N_iter 9: 0.554, 0.554, 0.002
# N_iter 10: 0.553, 0.553, 0.001
# N_iter 11: 0.553, 0.553, 0.000
# N_iter 12: 0.553, 0.553, 0.000
# N_iter 13: 0.553, 0.553, 0.000
# N_iter 14: 0.553, 0.553, 0.000
# N_iter 15: 0.553, 0.553, 0.000
# N_iter 16: 0.553, 0.553, 0.000
# N_iter 17: 0.553, 0.553, 0.000
# N_iter 18: 0.553, 0.553, 0.000
# N_iter 19: 0.553, 0.553, 0.000

# %% [markdown]
# 1. Calculate average, median, and standard deviation of data. - Average : 1.503, Median : 0.565, Stdev : 2.982
# 2. Calculate average, median, and standard deviation of data, after 1-sigma clipping for 1 time. - Average : 0.513, Median : 0.532, Stdev : 0.266
# 3. Calculate average, median, and standard deviation of data using 1-sigma clipping with more than 1 iterations. At which iteration are these three values stop to change? - After 11 times, those three values stop to change at average:0.553, median:0.553, stdev:0.000

# %%
import numpy as np
np.random.seed(123)
data = np.random.random((10, 20))
data[:, [3, 10]] += 10

# %%
print(data)
# Out:
# [[6.96469186e-01 2.86139335e-01 2.26851454e-01 1.05513148e+01
#   7.19468970e-01 4.23106460e-01 9.80764198e-01 6.84829739e-01
#   4.80931901e-01 3.92117518e-01 1.03431780e+01 7.29049707e-01
#   4.38572245e-01 5.96778966e-02 3.98044255e-01 7.37995406e-01
#   1.82491730e-01 1.75451756e-01 5.31551374e-01 5.31827587e-01]
#  [6.34400959e-01 8.49431794e-01 7.24455325e-01 1.06110235e+01
#   7.22443383e-01 3.22958914e-01 3.61788656e-01 2.28263231e-01
#   2.93714046e-01 6.30976124e-01 1.00921049e+01 4.33701173e-01
#   4.30862763e-01 4.93685098e-01 4.25830290e-01 3.12261223e-01
#   4.26351307e-01 8.93389163e-01 9.44160018e-01 5.01836676e-01]
#  [6.23952952e-01 1.15618395e-01 3.17285482e-01 1.04148262e+01
#   8.66309158e-01 2.50455365e-01 4.83034264e-01 9.85559786e-01
#   5.19485119e-01 6.12894526e-01 1.01206287e+01 8.26340801e-01
#   6.03060128e-01 5.45068006e-01 3.42763834e-01 3.04120789e-01
#   4.17022211e-01 6.81300766e-01 8.75456842e-01 5.10422337e-01]
# ...

# %% [markdown]
# 1. Do the median combine along the y-axis (in numpy, axis 0).
# 2. Do the median combine along the y-axis (in numpy, axis 0).

# %%
from matplotlib import pyplot as plt
from astropy.stats import sigma_clipped_stats
for i in [0, 3]:
    avg, med, std = sigma_clipped_stats(data, sigma=1, iters=i, axis=0)
    plt.plot(med, label=f"Niter = {i}", ls=':', marker='.')
plt.title("Median combine")
plt.grid(ls=':')
plt.legend()
plt.show()
